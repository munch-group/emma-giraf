# %% [markdown]
# # Visualisering af state space
#
# Her visualiserer jeg Markov-processen for at forstå modellens struktur.

# %%
graph.plot(nodesep=0.5, ranksep=0.5, rankdir="TB")

# %%
graph.plot(filename="coalescent_graph.png")

# %% [markdown]
# Grafen viser:
#
# - noder = states
# - kanter = coalescent events
# - vægte = transition rates
#
# Dette bruges til at verificere, at modellen er korrekt implementeret.
